# %% [markdown]
# ![Modern and Minimal Company Profile Presentation (1).jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # Pandas

# %% [markdown]
# # Import library

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Read csv data file

# %%
df = pd.read_csv('iris.csv')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Data inspection
# 1. Head
# 2. Tail
# 3. info
# 4. Describe

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.head(12)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa

# %%
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# # Data Selection and manipulation
# 1. single column name
# 2. multiple column by name
# 3. Select rows by condition
# 4. sort dataframe
# 5. Groupby
# 6. Add new value to dataframe
# 7.  rename any column in dataframe

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %% [markdown]
# # single column name

# %%
sepal_length = df['sepal_length']
sepal_length
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal_length, Length: 150, dtype: float64

# %% [markdown]
# # multiple column by name

# %%
cols = df[['sepal_length', 'sepal_width']]
cols
# Out:
#      sepal_length  sepal_width
# 0             5.1          3.5
# 1             4.9          3.0
# 2             4.7          3.2
# 3             4.6          3.1
# 4             5.0          3.6
# ..            ...          ...
# 145           6.7          3.0
# 146           6.3          2.5
# 147           6.5          3.0
# 148           6.2          3.4
# 149           5.9          3.0
#
# [150 rows x 2 columns]

# %% [markdown]
# # Select rows by condition

# %%
df[(df['sepal_length'] > 5) ]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# 14            5.8          4.0           1.2          0.2     setosa
# 15            5.7          4.4           1.5          0.4     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [118 rows x 5 columns]

# %% [markdown]
# # sort dataframe

# %%
sorted_df = df.sort_values('sepal_width')
sorted_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 60            5.0          2.0           3.5          1.0  versicolor
# 62            6.0          2.2           4.0          1.0  versicolor
# 119           6.0          2.2           5.0          1.5   virginica
# 68            6.2          2.2           4.5          1.5  versicolor
# 41            4.5          2.3           1.3          0.3      setosa
# ..            ...          ...           ...          ...         ...
# 16            5.4          3.9           1.3          0.4      setosa
# 14            5.8          4.0           1.2          0.2      setosa
# 32            5.2          4.1           1.5          0.1      setosa
# 33            5.5          4.2           1.4          0.2      setosa
# 15            5.7          4.4           1.5          0.4      setosa
#
# [150 rows x 5 columns]

# %% [markdown]
# # Groupby

# %%
# Group the data by a column and compute aggregate statistics
groupby_df = df.groupby('sepal_width').mean()
print(groupby_df)


groupby_df_max = df.groupby('sepal_width').max()
print(groupby_df_max)
# Out:
#              sepal_length  petal_length  petal_width
# sepal_width
# 2.0              5.000000      3.500000     1.000000
# 2.2              6.066667      4.500000     1.333333
# 2.3              5.325000      3.250000     0.975000
# 2.4              5.300000      3.600000     1.033333
# 2.5              5.762500      4.512500     1.550000
# 2.6              6.160000      4.880000     1.420000
# 2.7              5.855556      4.622222     1.555556
# 2.8              6.335714      5.042857     1.707143
# 2.9              6.060000      4.350000     1.320000
# 3.0              6.015385      4.234615     1.403846
# 3.1              5.941667      3.600000     1.141667
# 3.2              5.884615      3.753846     1.261538
# 3.3              6.016667      4.200000     1.566667
# 3.4              5.316667      2.466667     0.716667
# 3.5              5.150000      1.416667     0.300000
# 3.6              5.600000      2.833333     0.966667
# ...

# %% [markdown]
# # Add new value to dataframe

# %%
# add a new column
df['my_col']  = np.nan
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  my_col
# 0             5.1          3.5           1.4          0.2     setosa     NaN
# 1             4.9          3.0           1.4          0.2     setosa     NaN
# 2             4.7          3.2           1.3          0.2     setosa     NaN
# 3             4.6          3.1           1.5          0.2     setosa     NaN
# 4             5.0          3.6           1.4          0.2     setosa     NaN
# ..            ...          ...           ...          ...        ...     ...
# 145           6.7          3.0           5.2          2.3  virginica     NaN
# 146           6.3          2.5           5.0          1.9  virginica     NaN
# 147           6.5          3.0           5.2          2.0  virginica     NaN
# 148           6.2          3.4           5.4          2.3  virginica     NaN
# 149           5.9          3.0           5.1          1.8  virginica     NaN
#
# [150 rows x 6 columns]

# %%
rgn = np.random.default_rng()
df1 =rgn.random(10)


df['My_col1'] = rgn.random()
df


df['My_col3'] = df['sepal_length'].mean()
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  my_col  \
# 0             5.1          3.5           1.4          0.2     setosa     NaN
# 1             4.9          3.0           1.4          0.2     setosa     NaN
# 2             4.7          3.2           1.3          0.2     setosa     NaN
# 3             4.6          3.1           1.5          0.2     setosa     NaN
# 4             5.0          3.6           1.4          0.2     setosa     NaN
# ..            ...          ...           ...          ...        ...     ...
# 145           6.7          3.0           5.2          2.3  virginica     NaN
# 146           6.3          2.5           5.0          1.9  virginica     NaN
# 147           6.5          3.0           5.2          2.0  virginica     NaN
# 148           6.2          3.4           5.4          2.3  virginica     NaN
# 149           5.9          3.0           5.1          1.8  virginica     NaN
#
#       My_col1   My_col3
# ...

# %% [markdown]
# # rename any column in dataframe

# %%
df.columns

df.rename(columns={'My_col1' : 'Mean Of Sepal length', 'my_col' : 'nan_val'}, inplace = True)
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  nan_val  \
# 0             5.1          3.5           1.4          0.2     setosa      NaN
# 1             4.9          3.0           1.4          0.2     setosa      NaN
# 2             4.7          3.2           1.3          0.2     setosa      NaN
# 3             4.6          3.1           1.5          0.2     setosa      NaN
# 4             5.0          3.6           1.4          0.2     setosa      NaN
# ..            ...          ...           ...          ...        ...      ...
# 145           6.7          3.0           5.2          2.3  virginica      NaN
# 146           6.3          2.5           5.0          1.9  virginica      NaN
# 147           6.5          3.0           5.2          2.0  virginica      NaN
# 148           6.2          3.4           5.4          2.3  virginica      NaN
# 149           5.9          3.0           5.1          1.8  virginica      NaN
#
# ...

# %% [markdown]
# # Data cleaning
# 1. Drop_duplicate
# 2. dropna
# 3. fillna

# %%
df.drop_duplicates(inplace  = True)
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  nan_val  \
# 0             5.1          3.5           1.4          0.2     setosa      NaN
# 1             4.9          3.0           1.4          0.2     setosa      NaN
# 2             4.7          3.2           1.3          0.2     setosa      NaN
# 3             4.6          3.1           1.5          0.2     setosa      NaN
# 4             5.0          3.6           1.4          0.2     setosa      NaN
# ..            ...          ...           ...          ...        ...      ...
# 145           6.7          3.0           5.2          2.3  virginica      NaN
# 146           6.3          2.5           5.0          1.9  virginica      NaN
# 147           6.5          3.0           5.2          2.0  virginica      NaN
# 148           6.2          3.4           5.4          2.3  virginica      NaN
# 149           5.9          3.0           5.1          1.8  virginica      NaN
#
# ...

# %% [markdown]
# # Dropna

# %%
df.dropna(axis='columns' )
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  nan_val  \
# 0             5.1          3.5           1.4          0.2     setosa      NaN
# 1             4.9          3.0           1.4          0.2     setosa      NaN
# 2             4.7          3.2           1.3          0.2     setosa      NaN
# 3             4.6          3.1           1.5          0.2     setosa      NaN
# 4             5.0          3.6           1.4          0.2     setosa      NaN
# ..            ...          ...           ...          ...        ...      ...
# 145           6.7          3.0           5.2          2.3  virginica      NaN
# 146           6.3          2.5           5.0          1.9  virginica      NaN
# 147           6.5          3.0           5.2          2.0  virginica      NaN
# 148           6.2          3.4           5.4          2.3  virginica      NaN
# 149           5.9          3.0           5.1          1.8  virginica      NaN
#
# ...

# %%
df.fillna(10)
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  nan_val  \
# 0             5.1          3.5           1.4          0.2     setosa      NaN
# 1             4.9          3.0           1.4          0.2     setosa      NaN
# 2             4.7          3.2           1.3          0.2     setosa      NaN
# 3             4.6          3.1           1.5          0.2     setosa      NaN
# 4             5.0          3.6           1.4          0.2     setosa      NaN
# ..            ...          ...           ...          ...        ...      ...
# 145           6.7          3.0           5.2          2.3  virginica      NaN
# 146           6.3          2.5           5.0          1.9  virginica      NaN
# 147           6.5          3.0           5.2          2.0  virginica      NaN
# 148           6.2          3.4           5.4          2.3  virginica      NaN
# 149           5.9          3.0           5.1          1.8  virginica      NaN
#
# ...

# %% [markdown]
# # Do Follow InternBix for more Data related interesting and interesting stuff!
#
# ![internBix logo.png](data:image/png;base64,...)
